# %%
# %pip install spacy

# %%
# %pip install pytextrank
# Out:
# Collecting pytextrank
#   Downloading pytextrank-3.3.0-py3-none-any.whl.metadata (12 kB)
# Collecting GitPython>=3.1 (from pytextrank)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting graphviz>=0.13 (from pytextrank)
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Collecting icecream>=2.1 (from pytextrank)
#   Downloading icecream-2.1.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting networkx>=2.6 (from networkx[default]>=2.6->pytextrank)
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pygments>=2.7.4 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from pytextrank) (2.19.1)
# Collecting scipy>=1.7 (from pytextrank)
#   Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: spacy>=3.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from pytextrank) (3.8.3)
# Collecting gitdb<5,>=4.0.1 (from GitPython>=3.1->pytextrank)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: colorama>=0.3.9 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from icecream>=2.1->pytextrank) (0.4.6)
# Requirement already satisfied: executing>=2.1.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from icecream>=2.1->pytextrank) (2.2.0)
# Requirement already satisfied: asttokens>=2.0.1 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from icecream>=2.1->pytextrank) (3.0.0)
# Requirement already satisfied: numpy>=1.22 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from networkx[default]>=2.6->pytextrank) (2.0.2)
# Collecting matplotlib>=3.5 (from networkx[default]>=2.6->pytextrank)
#   Using cached matplotlib-3.9.4-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Collecting pandas>=1.4 (from networkx[default]>=2.6->pytextrank)
#   Using cached pandas-2.2.3-cp39-cp39-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (2.10.6)
# Requirement already satisfied: jinja2 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (58.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from spacy>=3.0->pytextrank) (3.5.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython>=3.1->pytextrank)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: language-data>=1.2 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3.0->pytextrank) (1.3.0)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.5->networkx[default]>=2.6->pytextrank)
#   Using cached contourpy-1.3.0-cp39-cp39-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.5->networkx[default]>=2.6->pytextrank)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.5->networkx[default]>=2.6->pytextrank)
#   Downloading fonttools-4.56.0-cp39-cp39-win_amd64.whl.metadata (103 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.5->networkx[default]>=2.6->pytextrank)
#   Using cached kiwisolver-1.4.7-cp39-cp39-win_amd64.whl.metadata (6.4 kB)
# Collecting pillow>=8 (from matplotlib>=3.5->networkx[default]>=2.6->pytextrank)
#   Using cached pillow-11.1.0-cp39-cp39-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.5->networkx[default]>=2.6->pytextrank)
#   Downloading pyparsing-3.2.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from matplotlib>=3.5->networkx[default]>=2.6->pytextrank) (2.9.0.post0)
# Collecting importlib-resources>=3.2.0 (from matplotlib>=3.5->networkx[default]>=2.6->pytextrank)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting pytz>=2020.1 (from pandas>=1.4->networkx[default]>=2.6->pytextrank)
#   Using cached pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.4->networkx[default]>=2.6->pytextrank)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0->pytextrank) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0->pytextrank) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0->pytextrank) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2025.1.31)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy>=3.0->pytextrank) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy>=3.0->pytextrank) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.0->pytextrank) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.0->pytextrank) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.0->pytextrank) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.0->pytextrank) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.0->pytextrank) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from jinja2->spacy>=3.0->pytextrank) (3.0.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5->networkx[default]>=2.6->pytextrank) (3.21.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3.0->pytextrank) (1.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5->networkx[default]>=2.6->pytextrank) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.0->pytextrank) (3.0.0)
# Requirement already satisfied: wrapt in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=3.0->pytextrank) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.0->pytextrank) (0.1.2)
# Downloading pytextrank-3.3.0-py3-none-any.whl (26 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
# Downloading icecream-2.1.4-py3-none-any.whl (14 kB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached matplotlib-3.9.4-cp39-cp39-win_amd64.whl (7.8 MB)
# Using cached pandas-2.2.3-cp39-cp39-win_amd64.whl (11.6 MB)
# Using cached contourpy-1.3.0-cp39-cp39-win_amd64.whl (211 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp39-cp39-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 41.2 MB/s eta 0:00:00
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached kiwisolver-1.4.7-cp39-cp39-win_amd64.whl (55 kB)
# Using cached pillow-11.1.0-cp39-cp39-win_amd64.whl (2.6 MB)
# Downloading pyparsing-3.2.2-py3-none-any.whl (111 kB)
# Using cached pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, smmap, scipy, pyparsing, pillow, networkx, kiwisolver, importlib-resources, icecream, graphviz, fonttools, cycler, contourpy, pandas, matplotlib, gitdb, GitPython, pytextrank
# Successfully installed GitPython-3.1.44 contourpy-1.3.0 cycler-0.12.1 fonttools-4.56.0 gitdb-4.0.12 graphviz-0.20.3 icecream-2.1.4 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 networkx-3.2.1 pandas-2.2.3 pillow-11.1.0 pyparsing-3.2.2 pytextrank-3.3.0 pytz-2025.1 scipy-1.13.1 smmap-5.0.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
import pytextrank

nlp = spacy.load("en_core_web_lg")
nlp.add_pipe("textrank")

example_text = """Deep learning (also known as deep structured learning) is part of a 
broader family of machine learning methods based on artificial neural networks with 
representation learning. Learning can be supervised, semi-supervised or unsupervised. 
Deep-learning architectures such as deep neural networks, deep belief networks, deep reinforcement learning, 
recurrent neural networks and convolutional neural networks have been applied to
fields including computer vision, speech recognition, natural language processing, 
machine translation, bioinformatics, drug design, medical image analysis, material
inspection and board game programs, where they have produced results comparable to 
and in some cases surpassing human expert performance. Artificial neural networks
(ANNs) were inspired by information processing and distributed communication nodes
in biological systems. ANNs have various differences from biological brains. Specifically, 
neural networks tend to be static and symbolic, while the biological brain of most living organisms
is dynamic (plastic) and analogue. The adjective "deep" in deep learning refers to the use of multiple
layers in the network. Early work showed that a linear perceptron cannot be a universal classifier, 
but that a network with a nonpolynomial activation function with one hidden layer of unbounded width can.
Deep learning is a modern variation which is concerned with an unbounded number of layers of bounded size, 
which permits practical application and optimized implementation, while retaining theoretical universality 
under mild conditions. In deep learning the layers are also permitted to be heterogeneous and to deviate widely 
from biologically informed connectionist models, for the sake of efficiency, trainability and understandability, 
whence the structured part."""
print('Original Document Size:',len(example_text))
doc = nlp(example_text)

for sent in doc._.textrank.summary(limit_phrases=2, limit_sentences=2):
    print(sent)
    print('Summary Length:',len(sent))
# Out:
# c:\Users\Fraser\OneDrive - Simon Fraser University (1sfu)\CMPT 420\TextSummarizer\.venv\lib\site-packages
# Original Document Size: 1820
# Deep-learning architectures such as deep neural networks, deep belief networks, deep reinforcement learning,
# recurrent neural networks and convolutional neural networks have been applied to
# fields including computer vision, speech recognition, natural language processing,
# machine translation, bioinformatics, drug design, medical image analysis, material
# inspection and board game programs, where they have produced results comparable to
# and in some cases surpassing human expert performance.
# Summary Length: 81
# Specifically,
# neural networks tend to be static and symbolic, while the biological brain of most living organisms
# is dynamic (plastic) and analogue.
# Summary Length: 29

# %%
# %pip install git+https://github.com/PyTorchLightning/pytorch-lightning
# %pip install git+https://github.com/huggingface/transformers
# %pip install sentencepiece
# %pip install git+https://github.com/stas00/transformers
# %pip install pegasus
# Out:
# Collecting git+https://github.com/PyTorchLightning/pytorch-lightning
#   Cloning https://github.com/PyTorchLightning/pytorch-lightning to c:\users\fraser\appdata\local\temp\pip-req-build-xt819m3b
#   Resolved https://github.com/PyTorchLightning/pytorch-lightning to commit 669486afdd524fb66c1afc36bf93955384ac1224
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting PyYAML<8.0,>=5.4 (from lightning==2.5.1rc2)
#   Downloading PyYAML-6.0.2-cp39-cp39-win_amd64.whl.metadata (2.1 kB)
# Collecting fsspec<2026.0,>=2022.5.0 (from fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1rc2)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning==2.5.1rc2)
#   Downloading lightning_utilities-0.14.2-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging<25.0,>=20.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from lightning==2.5.1rc2) (24.2)
# Collecting torch<4.0,>=2.1.0 (from lightning==2.5.1rc2)
#   Downloading torch-2.6.0-cp39-cp39-win_amd64.whl.metadata (28 kB)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning==2.5.1rc2)
#   Downloading torchmetrics-1.7.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from lightning==2.5.1rc2) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from lightning==2.5.1rc2) (4.12.2)
# Collecting pytorch-lightning (from lightning==2.5.1rc2)
#   Downloading pytorch_lightning-2.5.1-py3-none-any.whl.metadata (20 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1rc2)
#   Downloading aiohttp-3.11.14-cp39-cp39-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: setuptools in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from lightning-utilities<2.0,>=0.10.0->lightning==2.5.1rc2) (58.1.0)
# Collecting filelock (from torch<4.0,>=2.1.0->lightning==2.5.1rc2)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: networkx in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from torch<4.0,>=2.1.0->lightning==2.5.1rc2) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from torch<4.0,>=2.1.0->lightning==2.5.1rc2) (3.1.6)
# Collecting sympy==1.13.1 (from torch<4.0,>=2.1.0->lightning==2.5.1rc2)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch<4.0,>=2.1.0->lightning==2.5.1rc2)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy>1.20.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from torchmetrics<3.0,>=0.7.0->lightning==2.5.1rc2) (2.0.2)
# Requirement already satisfied: colorama in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from tqdm<6.0,>=4.57.0->lightning==2.5.1rc2) (0.4.6)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1rc2)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1rc2)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1rc2)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1rc2)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1rc2)
#   Downloading frozenlist-1.5.0-cp39-cp39-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1rc2)
#   Downloading multidict-6.2.0-cp39-cp39-win_amd64.whl.metadata (5.1 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1rc2)
#   Downloading propcache-0.3.0-cp39-cp39-win_amd64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1rc2)
#   Downloading yarl-1.18.3-cp39-cp39-win_amd64.whl.metadata (71 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from jinja2->torch<4.0,>=2.1.0->lightning==2.5.1rc2) (3.0.2)
# Requirement already satisfied: idna>=2.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1rc2) (3.10)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading lightning_utilities-0.14.2-py3-none-any.whl (28 kB)
# Downloading PyYAML-6.0.2-cp39-cp39-win_amd64.whl (162 kB)
# Downloading torch-2.6.0-cp39-cp39-win_amd64.whl (204.1 MB)
#    ---------------------------------------- 0.0/204.1 MB ? eta -:--:--
#    - -------------------------------------- 8.4/204.1 MB 43.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 22.0/204.1 MB 63.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 23.1/204.1 MB 52.1 MB/s eta 0:00:04
#    ---- ----------------------------------- 23.9/204.1 MB 29.0 MB/s eta 0:00:07
#    -------- ------------------------------- 41.2/204.1 MB 40.3 MB/s eta 0:00:05
#    --------- ------------------------------ 46.1/204.1 MB 42.6 MB/s eta 0:00:04
#    --------- ------------------------------ 49.3/204.1 MB 35.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 52.4/204.1 MB 32.7 MB/s eta 0:00:05
#    ------------ --------------------------- 61.9/204.1 MB 34.6 MB/s eta 0:00:05
#    ------------ --------------------------- 64.0/204.1 MB 31.9 MB/s eta 0:00:05
#    ------------ --------------------------- 64.0/204.1 MB 31.9 MB/s eta 0:00:05
#    ------------ --------------------------- 65.0/204.1 MB 27.3 MB/s eta 0:00:06
#    --------------- ------------------------ 76.5/204.1 MB 29.4 MB/s eta 0:00:05
#    ---------------- ----------------------- 83.9/204.1 MB 29.7 MB/s eta 0:00:05
#    ------------------ --------------------- 96.5/204.1 MB 31.6 MB/s eta 0:00:04
#    -------------------- ------------------ 105.9/204.1 MB 32.7 MB/s eta 0:00:04
#    --------------------- ----------------- 110.1/204.1 MB 32.8 MB/s eta 0:00:03
#    --------------------- ----------------- 114.6/204.1 MB 31.1 MB/s eta 0:00:03
#    ------------------------- ------------- 134.2/204.1 MB 34.7 MB/s eta 0:00:03
#    ---------------------------- ---------- 147.1/204.1 MB 35.9 MB/s eta 0:00:02
#    ------------------------------ -------- 158.3/204.1 MB 37.5 MB/s eta 0:00:02
#    ---------------------------------- ---- 178.3/204.1 MB 39.7 MB/s eta 0:00:01
#    ------------------------------------ -- 188.7/204.1 MB 40.2 MB/s eta 0:00:01
#    ------------------------------------- - 196.3/204.1 MB 40.0 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 40.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 40.6 MB/s eta 0:00:01
#    --------------------------------------- 204.1/204.1 MB 38.3 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ---------------------------------------- 6.2/6.2 MB 54.4 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.0-py3-none-any.whl (960 kB)
#    ---------------------------------------- 0.0/960.9 kB ? eta -:--:--
#    --------------------------------------- 960.9/960.9 kB 43.7 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.1-py3-none-any.whl (822 kB)
#    ---------------------------------------- 0.0/823.0 kB ? eta -:--:--
#    --------------------------------------- 823.0/823.0 kB 35.1 MB/s eta 0:00:00
# Downloading aiohttp-3.11.14-cp39-cp39-win_amd64.whl (443 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading frozenlist-1.5.0-cp39-cp39-win_amd64.whl (51 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading multidict-6.2.0-cp39-cp39-win_amd64.whl (29 kB)
# Downloading propcache-0.3.0-cp39-cp39-win_amd64.whl (45 kB)
# Downloading yarl-1.18.3-cp39-cp39-win_amd64.whl (90 kB)
# Building wheels for collected packages: lightning
#   Building wheel for lightning (pyproject.toml): started
#   Building wheel for lightning (pyproject.toml): finished with status 'done'
#   Created wheel for lightning: filename=lightning-2.5.1rc2-py3-none-any.whl size=824202 sha256=09aca95d7ae439ad456d7855116dcce54a24b709428831715c48c819bea64242
#   Stored in directory: C:\Users\Fraser\AppData\Local\Temp\pip-ephem-wheel-cache-m36f47nn\wheels\71\cd\86\0fcffbab9766493276c053f69e3cda436783f811f28fecc3ab
# Successfully built lightning
# Installing collected packages: mpmath, sympy, PyYAML, propcache, multidict, lightning-utilities, fsspec, frozenlist, filelock, attrs, async-timeout, aiohappyeyeballs, yarl, torch, aiosignal, torchmetrics, aiohttp, pytorch-lightning, lightning
# Successfully installed PyYAML-6.0.2 aiohappyeyeballs-2.6.1 aiohttp-3.11.14 aiosignal-1.3.2 async-timeout-5.0.1 attrs-25.3.0 filelock-3.18.0 frozenlist-1.5.0 fsspec-2025.3.0 lightning-2.5.1rc2 lightning-utilities-0.14.2 mpmath-1.3.0 multidict-6.2.0 propcache-0.3.0 pytorch-lightning-2.5.1 sympy-1.13.1 torch-2.6.0 torchmetrics-1.7.0 yarl-1.18.3
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/PyTorchLightning/pytorch-lightning 'C:\Users\Fraser\AppData\Local\Temp\pip-req-build-xt819m3b'
#   Running command git submodule update --init --recursive -q
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to c:\users\fraser\appdata\local\temp\pip-req-build-rc31ptcv
#   Resolved https://github.com/huggingface/transformers to commit c9d1e5238a752813ba91a8751a638a09b5efbb73
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: filelock in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.51.0.dev0) (3.18.0)
# Collecting huggingface-hub<1.0,>=0.26.0 (from transformers==4.51.0.dev0)
#   Downloading huggingface_hub-0.29.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.51.0.dev0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.51.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.51.0.dev0) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers==4.51.0.dev0)
#   Downloading regex-2024.11.6-cp39-cp39-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.51.0.dev0) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers==4.51.0.dev0)
#   Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers==4.51.0.dev0)
#   Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.51.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.51.0.dev0) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.51.0.dev0) (4.12.2)
# Requirement already satisfied: colorama in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from tqdm>=4.27->transformers==4.51.0.dev0) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from requests->transformers==4.51.0.dev0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from requests->transformers==4.51.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from requests->transformers==4.51.0.dev0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from requests->transformers==4.51.0.dev0) (2025.1.31)
# Downloading huggingface_hub-0.29.3-py3-none-any.whl (468 kB)
# Downloading regex-2024.11.6-cp39-cp39-win_amd64.whl (274 kB)
# Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 46.2 MB/s eta 0:00:00
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml): started
#   Building wheel for transformers (pyproject.toml): finished with status 'done'
#   Created wheel for transformers: filename=transformers-4.51.0.dev0-py3-none-any.whl size=11005171 sha256=5bc86a87aa6d18f1dfc31334ef727c4602ee5f42951641f825ca4a36d5b46dd2
#   Stored in directory: C:\Users\Fraser\AppData\Local\Temp\pip-ephem-wheel-cache-beubpm1n\wheels\14\a0\7b\8f6b25ba4110aa215fcb8d6aedd6cd4f9b9b6619190999ac2b
# Successfully built transformers
# Installing collected packages: safetensors, regex, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.29.3 regex-2024.11.6 safetensors-0.5.3 tokenizers-0.21.1 transformers-4.51.0.dev0
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers 'C:\Users\Fraser\AppData\Local\Temp\pip-req-build-rc31ptcv'
# Collecting sentencepieceNote: you may need to restart the kernel to use updated packages.
#
#   Downloading sentencepiece-0.2.0-cp39-cp39-win_amd64.whl.metadata (8.3 kB)
# Downloading sentencepiece-0.2.0-cp39-cp39-win_amd64.whl (991 kB)
#    ---------------------------------------- 0.0/991.5 kB ? eta -:--:--
#    --------------------------------------- 991.5/991.5 kB 23.5 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.0
# Collecting git+https://github.com/stas00/transformers
#   Cloning https://github.com/stas00/transformers to c:\users\fraser\appdata\local\temp\pip-req-build-0lpgjzdj
#   Resolved https://github.com/stas00/transformers to commit 94ae1ba5b55e79ba766582de8a199d8ccf24a021
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: filelock in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.50.0.dev0) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.50.0.dev0) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.50.0.dev0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.50.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.50.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.50.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.50.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.50.0.dev0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.50.0.dev0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from transformers==4.50.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.50.0.dev0) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.50.0.dev0) (4.12.2)
# Requirement already satisfied: colorama in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from tqdm>=4.27->transformers==4.50.0.dev0) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from requests->transformers==4.50.0.dev0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from requests->transformers==4.50.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from requests->transformers==4.50.0.dev0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fraser\onedrive - simon fraser university (1sfu)\cmpt 420\textsummarizer\.venv\lib\site-packages (from requests->transformers==4.50.0.dev0) (2025.1.31)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml): started
#   Building wheel for transformers (pyproject.toml): finished with status 'done'
#   Created wheel for transformers: filename=transformers-4.50.0.dev0-py3-none-any.whl size=10878031 sha256=f20dcc668ec2fb91258e8e0fd7226a44e7158e4694b514e86d3c56b982bb19da
#   Stored in directory: C:\Users\Fraser\AppData\Local\Temp\pip-ephem-wheel-cache-pn9082i1\wheels\b6\c2\16\9e033b8e233014b0b320fb6e034917495f3ff229fb458616fe
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.0.dev0
#     Uninstalling transformers-4.51.0.dev0:
#       Successfully uninstalled transformers-4.51.0.dev0
# Successfully installed transformers-4.50.0.dev0
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/stas00/transformers 'C:\Users\Fraser\AppData\Local\Temp\pip-req-build-0lpgjzdj'
# Collecting pegasus
#   Downloading pegasus-0.1.3.tar.gz (8.7 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: pegasus
#   Building wheel for pegasus (pyproject.toml): started
#   Building wheel for pegasus (pyproject.toml): finished with status 'done'
#   Created wheel for pegasus: filename=pegasus-0.1.3-py3-none-any.whl size=6517 sha256=01595076db9edecee7ee86cf74b67159fb412e069af21ace6a44df0750f07762
#   Stored in directory: c:\users\fraser\appdata\local\pip\cache\wheels\d4\ec\88\aea73f75294fd19f71e77e12e8e0a05a322a8d330c91c876a8
# Successfully built pegasus
# Installing collected packages: pegasus
# Successfully installed pegasus-0.1.3
# Note: you may need to restart the kernel to use updated packages.
